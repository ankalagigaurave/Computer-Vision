# %% [markdown]
# <a href="https://colab.research.google.com/github/ankalagigaurave/Computer-Vision/blob/main/Assignment/CV_A4_J004.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2 
import numpy as np 
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from skimage.color import rgb2hsv, rgb2gray, rgb2yuv
from skimage import color, exposure, transform
from scipy import ndimage

# %%
tsu_1 = cv2.imread('/content/The Warrior.jpg') 
tsu_3_1 = mpimg.imread('/content/The Warrior.jpg')
tsu_2 = cv2.imread('/content/The Warrior.jpg', cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(tsu_1)
plt.title('Aesthetic Warrior')
# Out:
# Text(0.5, 1.0, 'Aesthetic Warrior')

# %%
plt.imshow(tsu_1)
plt.title('Aesthetic Warrior OpenCV colour scheme')
# Out:
# Text(0.5, 1.0, 'Aesthetic Warrior OpenCV colour scheme')

# %%
kernel = np.ones((5, 5), np.float32) / 9
tsu_war = cv2.filter2D(tsu_1, -1, kernel)
plt.imshow(tsu_war)
plt.title('Convolution (5,5) filter')
# Out:
# Text(0.5, 1.0, 'Convolution (5,5) filter')

# %%
kernel_sharp = np.array([[0, -1, 0],
                   [-1, 5, -1],
                   [0, -1, 0]])
tsu_war = cv2.filter2D(tsu_1, -1, kernel_sharp)
plt.imshow(tsu_war)
plt.title('Convolution (3,3) filter')
# Out:
# Text(0.5, 1.0, 'Convolution (3,3) filter')
