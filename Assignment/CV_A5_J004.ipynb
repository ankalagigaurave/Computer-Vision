# %% [markdown]
# <a href="https://colab.research.google.com/github/ankalagigaurave/Computer-Vision/blob/main/Assignment/CV_A5_J004.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2 
import numpy as np 
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from skimage.color import rgb2hsv, rgb2gray, rgb2yuv
from skimage import color, exposure, transform
from scipy import ndimage

# %%
tsu_1 = cv2.imread('/content/The Warrior.jpg') 
tsu_3_1 = mpimg.imread('/content/The Warrior.jpg')
tsu_2 = cv2.imread('/content/The Warrior.jpg', cv2.IMREAD_GRAYSCALE)

# %%
tsu_blur = cv2.blur(tsu_1, (21,21))
plt.imshow(tsu_blur)

# %%
tsu_gauss = cv2.GaussianBlur(tsu_1, (21,21), sigmaX = 150)
plt.imshow(tsu_gauss)
